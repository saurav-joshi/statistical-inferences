# %% [markdown]
#  ### First_ Notebook and I am exited

# %%
library(dplyr)

# %%
movie<-read.csv("dataset/M2_Movie_Metadata.csv", header=TRUE)

# %%
movie
# Out:
#      color            director_name      num_critic_for_reviews duration
# 1    Color            James Cameron      723                    178
# 2    Color            Gore Verbinski     302                    169
# 3    Color            Sam Mendes         602                    148
# 4    Color            Christopher Nolan  813                    164
# 5                     Doug Walker         NA                     NA
# 6    Color            Andrew Stanton     462                    132
# 7    Color            Sam Raimi          392                    156
# 8    Color            Nathan Greno       324                    100
# 9    Color            Joss Whedon        635                    141
# 10   Color            David Yates        375                    153
# 11   Color            Zack Snyder        673                    183
# 12   Color            Bryan Singer       434                    169
# 13   Color            Marc Forster       403                    106
# ...

# %%
#movie$director_name #-----> accessing a data field
#names(movie) #-----> names of the headers
#ls()    #----> objects in an enviornment
#str(movie)   #---> structure of
#dim(movie) #---> dimensions of an object
#class(movie$director_name) #---> class of an object (int, Factor, chr)
#head(movie, n=10) #---> top n 
#tail(movie, n=5) ---> bottom n

# %%
##print(subset(movie, color == "Black and White"))
##print(subset(movie, color == " Black and White"))
bw<-subset(movie, color == " Black and White")

#print(bw<-movie[which(movie$color == " Black and White")])

#mydata[ which(mydata$gender=='F' & mydata$age > 65), ]

# %%
bw
# Out:
#      color            director_name       num_critic_for_reviews duration
# 112   Black and White Michael Bay         191                    184
# 150   Black and White Lee Tamahori        264                    133
# 258   Black and White Martin Scorsese     267                    170
# 273   Black and White Michael Mann        174                    165
# 287   Black and White Martin Campbell     400                    144
# 302   Black and White Stefen Fangmeier    170                    104
# 394   Black and White Gary Ross           175                    140
# 480   Black and White                      31                     25
# 498   Black and White Rob Marshall        205                    118
# 521   Black and White Stephen Norrington  202                    110
# 605   Black and White Steven Spielberg    388                    146
# 665   Black and White Clint Eastwood      169                    130
# 692   Black and White Frank Miller        339                    102
# ...

# %%
print(movie2<-movie[,c(2,5)])
# Out:
#                         director_name director_facebook_likes
# 1                       James Cameron                       0
# 2                      Gore Verbinski                     563
# 3                          Sam Mendes                       0
# 4                   Christopher Nolan                   22000
# 5                         Doug Walker                     131
# 6                      Andrew Stanton                     475
# 7                           Sam Raimi                       0
# 8                        Nathan Greno                      15
# 9                         Joss Whedon                       0
# 10                        David Yates                     282
# 11                        Zack Snyder                       0
# 12                       Bryan Singer                       0
# 13                       Marc Forster                     395
# 14                     Gore Verbinski                     563
# ...

# %%
bw
# Out:
#      color            director_name       num_critic_for_reviews duration
# 112   Black and White Michael Bay         191                    184
# 150   Black and White Lee Tamahori        264                    133
# 258   Black and White Martin Scorsese     267                    170
# 273   Black and White Michael Mann        174                    165
# 287   Black and White Martin Campbell     400                    144
# 302   Black and White Stefen Fangmeier    170                    104
# 394   Black and White Gary Ross           175                    140
# 480   Black and White                      31                     25
# 498   Black and White Rob Marshall        205                    118
# 521   Black and White Stephen Norrington  202                    110
# 605   Black and White Steven Spielberg    388                    146
# 665   Black and White Clint Eastwood      169                    130
# 692   Black and White Frank Miller        339                    102
# ...

# %%
print(movie$movie_title<-sub(pattern="A", replacement="",movie$movie_title))
# Out:
#    [1] "vatarÂ "
#    [2] "Pirates of the Caribbean: t World's EndÂ "
#    [3] "SpectreÂ "
#    [4] "The Dark Knight RisesÂ "
#    [5] "Star Wars: Episode VII - The Force wakensÂ             "
#    [6] "John CarterÂ "
#    [7] "Spider-Man 3Â "
#    [8] "TangledÂ "
#    [9] "vengers: Age of UltronÂ "
#   [10] "Harry Potter and the Half-Blood PrinceÂ "
#   [11] "Batman v Superman: Dawn of JusticeÂ "
#   [12] "Superman ReturnsÂ "
#   [13] "Quantum of SolaceÂ "
#   [14] "Pirates of the Caribbean: Dead Man's ChestÂ "
#   [15] "The Lone RangerÂ "
#   [16] "Man of SteelÂ "
#   [17] "The Chronicles of Narnia: Prince CaspianÂ "
#   [18] "The vengersÂ "
#   [19] "Pirates of the Caribbean: On Stranger TidesÂ "
#   [20] "Men in Black 3Â "
#   [21] "The Hobbit: The Battle of the Five rmiesÂ "
#   [22] "The mazing Spider-ManÂ "
#   [23] "Robin HoodÂ "
#   [24] "The Hobbit: The Desolation of SmaugÂ "
#   [25] "The Golden CompassÂ "
#   [26] "King KongÂ "
#   [27] "TitanicÂ "
# ...

# %%
?sub
# Out:
# starting httpd help server ... done

# %%
movie1<-movie
movie1$profit<-movie1$gross-movie$budget

# %%
cbind(movie1, movie1$profit)
# Out:
#      color            director_name      num_critic_for_reviews duration
# 1    Color            James Cameron      723                    178
# 2    Color            Gore Verbinski     302                    169
# 3    Color            Sam Mendes         602                    148
# 4    Color            Christopher Nolan  813                    164
# 5                     Doug Walker         NA                     NA
# 6    Color            Andrew Stanton     462                    132
# 7    Color            Sam Raimi          392                    156
# 8    Color            Nathan Greno       324                    100
# 9    Color            Joss Whedon        635                    141
# 10   Color            David Yates        375                    153
# 11   Color            Zack Snyder        673                    183
# 12   Color            Bryan Singer       434                    169
# 13   Color            Marc Forster       403                    106
# ...

# %%
movie1_profit<-movie[order(-movie1$profit),]
cbind(movie1, movie1_profit)
head(movie1_profit$movie_title,10)
# Out:
#      color            director_name      num_critic_for_reviews duration
# 1    Color            James Cameron      723                    178
# 30   Color            Gore Verbinski     302                    169
# 27   Color            Sam Mendes         602                    148
# 3025 Color            Christopher Nolan  813                    164
# 3081                  Doug Walker         NA                     NA
# 18   Color            Andrew Stanton     462                    132
# 795  Color            Sam Raimi          392                    156
# 510  Color            Nathan Greno       324                    100
# 241  Color            Joss Whedon        635                    141
# 67   Color            David Yates        375                    153
# 440  Color            Zack Snyder        673                    183
# 813  Color            Bryan Singer       434                    169
# 187  Color            Marc Forster       403                    106
# ...

# %%
profit<-movie1_profit[1:10]

# %%
profit
# Out:
#      color            director_name      num_critic_for_reviews duration
# 1    Color            James Cameron      723                    178
# 30   Color            Colin Trevorrow    644                    124
# 27   Color            James Cameron      315                    194
# 3025 Color            George Lucas       282                    125
# 3081 Color            Steven Spielberg   215                    120
# 18   Color            Joss Whedon        703                    173
# 795  Color            Joss Whedon        703                    173
# 510  Color            Roger Allers       186                     73
# 241  Color            George Lucas       320                    136
# 67   Color            Christopher Nolan  645                    152
# 440  Color            Gary Ross          673                    142
# 813  Color            Tim Miller         579                    108
# 187  Color            Francis Lawrence   502                    146
# ...

# %%
hist(movie1$profit)
# Out:
# Plot with title "Histogram of movie1$profit"
